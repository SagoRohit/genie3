# %%
# !git clone https://github.com/PayamDiba/SERGIO

# %%
# !git clone https://github.com/SagoRohit/genie3.git

# %%
# !git pull origin main

# %%
# %cd genie3

# %%
# !ls

# %%
# !python sergio_prepare_data.py

# %%
# !pip install numpy pandas anndata scikit-learn matplotlib arboreto scanpy

# %%
# !ls

# %%
# %%bash
#
# declare -A TIERS=( [1]=15 [2]=5 [3]=3 )
# for tier in 1 2 3; do
#   n_tp=${TIERS[$tier]}
#   for seed in 0 1 2; do
#     python genie3/sergio_prepare_data.py \
#       --dataset_dir /kaggle/working/SERGIO/data_sets/De-noised_400G_9T_300cPerT_5_DS2 \
#       --n_bins 9 --n_replicates 15 \
#       --n_timepoints_keep $n_tp --seed $seed \
#       --out_dir data/data_tier${tier}_seed${seed}
#   done
# done

# %%
# !python run_genie3_sergio.py \
    --data_root ../data \
    --results_root results \
    --log_file results/genie3_density_experiment_log.txt \
    --n_estimators 100

# %%
# !ls

# %%
# %cd results

# %%
# !ls

# %%
# !ls

# %%
# !python make_comparison_outputs.py

# %%
# !tar -czvf results.tar.gz /kaggle/working/genie3/results

# %%
# !ls
# Out:
# eval_utils.py			     __pycache__  run_genie3_sergio.py
# make_comparison_outputs.py	     README.md	  sergio_prepare_data.py
# marlene_density_results_summary.csv  results

# %%
from IPython.display import FileLink

# Generate download link for the CSV
display(FileLink(r'results/model_comparison_summary.csv'))

# Generate download link for the PDF
display(FileLink(r'results/model_comparison_degradation_curve.pdf'))
# Out:
# /kaggle/working/genie3/results/model_comparison_summary.csv
# /kaggle/working/genie3/results/model_comparison_degradation_curve.pdf
